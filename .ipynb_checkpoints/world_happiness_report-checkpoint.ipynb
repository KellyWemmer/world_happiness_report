# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Gathering, joining, and cleaning

# %%
#I'm interested in type of healthcare, cost of living, education systems, etc.
df19 = pd.read_csv('2019.csv')
df19 = df19.head(20)
df19
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 0              1           Finland  7.769           1.340           1.587
# 1              2           Denmark  7.600           1.383           1.573
# 2              3            Norway  7.554           1.488           1.582
# 3              4           Iceland  7.494           1.380           1.624
# 4              5       Netherlands  7.488           1.396           1.522
# 5              6       Switzerland  7.480           1.452           1.526
# 6              7            Sweden  7.343           1.387           1.487
# 7              8       New Zealand  7.307           1.303           1.557
# 8              9            Canada  7.278           1.365           1.505
# 9             10           Austria  7.246           1.376           1.475
# 10            11         Australia  7.228           1.372           1.548
# 11            12        Costa Rica  7.167           1.034           1.441
# 12            13            Israel  7.139           1.276           1.455
# 13            14        Luxembourg  7.090           1.609           1.479
# 14            15    United Kingdom  7.054           1.333           1.538
# 15            16           Ireland  7.021           1.499           1.553
# 16            17           Germany  6.985           1.373           1.454
# 17            18           Belgium  6.923           1.356           1.504
# 18            19     United States  6.892           1.433           1.457
# 19            20    Czech Republic  6.852           1.269           1.487
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                     0.986                         0.596       0.153
# 1                     0.996                         0.592       0.252
# 2                     1.028                         0.603       0.271
# 3                     1.026                         0.591       0.354
# 4                     0.999                         0.557       0.322
# 5                     1.052                         0.572       0.263
# 6                     1.009                         0.574       0.267
# 7                     1.026                         0.585       0.330
# 8                     1.039                         0.584       0.285
# 9                     1.016                         0.532       0.244
# 10                    1.036                         0.557       0.332
# 11                    0.963                         0.558       0.144
# 12                    1.029                         0.371       0.261
# 13                    1.012                         0.526       0.194
# 14                    0.996                         0.450       0.348
# 15                    0.999                         0.516       0.298
# 16                    0.987                         0.495       0.261
# 17                    0.986                         0.473       0.160
# 18                    0.874                         0.454       0.280
# 19                    0.920                         0.457       0.046
#
#     Perceptions of corruption
# 0                       0.393
# 1                       0.410
# 2                       0.341
# 3                       0.118
# 4                       0.298
# 5                       0.343
# 6                       0.373
# 7                       0.380
# 8                       0.308
# 9                       0.226
# 10                      0.290
# 11                      0.093
# 12                      0.082
# 13                      0.316
# 14                      0.278
# 15                      0.310
# 16                      0.265
# 17                      0.210
# 18                      0.128
# 19                      0.036

# %%
df19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 9 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  20 non-null     int64
#  1   Country or region             20 non-null     object
#  2   Score                         20 non-null     float64
#  3   GDP per capita                20 non-null     float64
#  4   Social support                20 non-null     float64
#  5   Healthy life expectancy       20 non-null     float64
#  6   Freedom to make life choices  20 non-null     float64
#  7   Generosity                    20 non-null     float64
#  8   Perceptions of corruption     20 non-null     float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 1.5+ KB

# %%
#Healthcare Information taken from Wikipedia https://en.wikipedia.org/wiki/Health_care_systems_by_country
#Alphabetise by country
df19 = df19.sort_values("Country or region")
df19
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 10            11         Australia  7.228           1.372           1.548
# 9             10           Austria  7.246           1.376           1.475
# 17            18           Belgium  6.923           1.356           1.504
# 8              9            Canada  7.278           1.365           1.505
# 11            12        Costa Rica  7.167           1.034           1.441
# 19            20    Czech Republic  6.852           1.269           1.487
# 1              2           Denmark  7.600           1.383           1.573
# 0              1           Finland  7.769           1.340           1.587
# 16            17           Germany  6.985           1.373           1.454
# 3              4           Iceland  7.494           1.380           1.624
# 15            16           Ireland  7.021           1.499           1.553
# 12            13            Israel  7.139           1.276           1.455
# 13            14        Luxembourg  7.090           1.609           1.479
# 4              5       Netherlands  7.488           1.396           1.522
# 7              8       New Zealand  7.307           1.303           1.557
# 2              3            Norway  7.554           1.488           1.582
# 6              7            Sweden  7.343           1.387           1.487
# 5              6       Switzerland  7.480           1.452           1.526
# 14            15    United Kingdom  7.054           1.333           1.538
# 18            19     United States  6.892           1.433           1.457
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 10                    1.036                         0.557       0.332
# 9                     1.016                         0.532       0.244
# 17                    0.986                         0.473       0.160
# 8                     1.039                         0.584       0.285
# 11                    0.963                         0.558       0.144
# 19                    0.920                         0.457       0.046
# 1                     0.996                         0.592       0.252
# 0                     0.986                         0.596       0.153
# 16                    0.987                         0.495       0.261
# 3                     1.026                         0.591       0.354
# 15                    0.999                         0.516       0.298
# 12                    1.029                         0.371       0.261
# 13                    1.012                         0.526       0.194
# 4                     0.999                         0.557       0.322
# 7                     1.026                         0.585       0.330
# 2                     1.028                         0.603       0.271
# 6                     1.009                         0.574       0.267
# 5                     1.052                         0.572       0.263
# 14                    0.996                         0.450       0.348
# 18                    0.874                         0.454       0.280
#
#     Perceptions of corruption
# 10                      0.290
# 9                       0.226
# 17                      0.210
# 8                       0.308
# 11                      0.093
# 19                      0.036
# 1                       0.410
# 0                       0.393
# 16                      0.265
# 3                       0.118
# 15                      0.310
# 12                      0.082
# 13                      0.316
# 4                       0.298
# 7                       0.380
# 2                       0.341
# 6                       0.373
# 5                       0.343
# 14                      0.278
# 18                      0.128

# %%
#Create function to get type of healthcare system
#Healthcare Information taken from Wikipedia https://en.wikipedia.org/wiki/Health_care_systems_by_country
def healthcare(country):
    if country['Country or region'] == 'Australia' or country['Country or region'] == 'Canada' or country['Country or region'] == 'Costa Rica' or country['Country or region'] == 'Denmark' or country['Country or region'] == 'Finland' or country['Country or region'] == 'Iceland' or country['Country or region'] == 'Ireland' or country['Country or region'] == 'New Zealand' or country['Country or region'] == 'Norway' or country['Country or region'] == 'Sweden' or country['Country or region'] == 'United Kingdom':
        return 'Universal government-funded'
    if country['Country or region'] == 'Belgium' or country['Country or region'] == 'Luxembourg' or country['Country or region'] == 'Czech Republic':
        return 'Universal public'
    if country['Country or region'] == 'Austria' or country['Country or region'] == 'Germany':
        return 'Public private'
    if country['Country or region'] == 'Israel' or country['Country or region'] == 'Netherlands' or country['Country or region'] == 'Switzerland':
        return 'Universal private'
    if country['Country or region'] == 'United States':
        return 'Non-universal'
    else:
        return 'Other'

# %%
df19.apply(lambda country:healthcare(country), axis=1)
# Out:
# 10    Universal government-funded
# 9                  Public private
# 17               Universal public
# 8     Universal government-funded
# 11    Universal government-funded
# 19               Universal public
# 1     Universal government-funded
# 0     Universal government-funded
# 16                 Public private
# 3     Universal government-funded
# 15    Universal government-funded
# 12              Universal private
# 13               Universal public
# 4               Universal private
# 7     Universal government-funded
# 2     Universal government-funded
# 6     Universal government-funded
# 5               Universal private
# 14    Universal government-funded
# 18                  Non-universal
# dtype: object

# %%
df19['Healthcare system'] = df19.apply(lambda country:healthcare(country), axis=1)
df19.sort_values("Overall rank")
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 0              1           Finland  7.769           1.340           1.587
# 1              2           Denmark  7.600           1.383           1.573
# 2              3            Norway  7.554           1.488           1.582
# 3              4           Iceland  7.494           1.380           1.624
# 4              5       Netherlands  7.488           1.396           1.522
# 5              6       Switzerland  7.480           1.452           1.526
# 6              7            Sweden  7.343           1.387           1.487
# 7              8       New Zealand  7.307           1.303           1.557
# 8              9            Canada  7.278           1.365           1.505
# 9             10           Austria  7.246           1.376           1.475
# 10            11         Australia  7.228           1.372           1.548
# 11            12        Costa Rica  7.167           1.034           1.441
# 12            13            Israel  7.139           1.276           1.455
# 13            14        Luxembourg  7.090           1.609           1.479
# 14            15    United Kingdom  7.054           1.333           1.538
# 15            16           Ireland  7.021           1.499           1.553
# 16            17           Germany  6.985           1.373           1.454
# 17            18           Belgium  6.923           1.356           1.504
# 18            19     United States  6.892           1.433           1.457
# 19            20    Czech Republic  6.852           1.269           1.487
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                     0.986                         0.596       0.153
# 1                     0.996                         0.592       0.252
# 2                     1.028                         0.603       0.271
# 3                     1.026                         0.591       0.354
# 4                     0.999                         0.557       0.322
# 5                     1.052                         0.572       0.263
# 6                     1.009                         0.574       0.267
# 7                     1.026                         0.585       0.330
# 8                     1.039                         0.584       0.285
# 9                     1.016                         0.532       0.244
# 10                    1.036                         0.557       0.332
# 11                    0.963                         0.558       0.144
# 12                    1.029                         0.371       0.261
# 13                    1.012                         0.526       0.194
# 14                    0.996                         0.450       0.348
# 15                    0.999                         0.516       0.298
# 16                    0.987                         0.495       0.261
# 17                    0.986                         0.473       0.160
# 18                    0.874                         0.454       0.280
# 19                    0.920                         0.457       0.046
#
#     Perceptions of corruption            Healthcare system
# 0                       0.393  Universal government-funded
# 1                       0.410  Universal government-funded
# 2                       0.341  Universal government-funded
# 3                       0.118  Universal government-funded
# 4                       0.298            Universal private
# 5                       0.343            Universal private
# 6                       0.373  Universal government-funded
# 7                       0.380  Universal government-funded
# 8                       0.308  Universal government-funded
# 9                       0.226               Public private
# 10                      0.290  Universal government-funded
# 11                      0.093  Universal government-funded
# 12                      0.082            Universal private
# 13                      0.316             Universal public
# 14                      0.278  Universal government-funded
# 15                      0.310  Universal government-funded
# 16                      0.265               Public private
# 17                      0.210             Universal public
# 18                      0.128                Non-universal
# 19                      0.036             Universal public

# %%
#cost of living information received from https://www.worlddata.info/cost-of-living.php
living_cost = pd.read_csv('Cost_of_living.csv')
living_cost = living_cost.rename(columns={'Country': 'Country or region'})
living_cost.head(20)
# Out:
#    Country or region  Cost of living index Monthly income  \
# 0     Cayman Islands                 195.0       3928 USD
# 1            Bermuda                 190.3       8845 USD
# 2        Switzerland                 144.3       7125 USD
# 3            Iceland                 135.1       6071 USD
# 4     Virgin Islands                 133.8       1161 USD
# 5             Norway                 130.5       6875 USD
# 6             Israel                 118.9       3608 USD
# 7            Denmark                 118.4       5270 USD
# 8            Bahamas                 116.0       2648 USD
# 9         Luxembourg                 111.4       6159 USD
# 10         Singapore                 111.1       4966 USD
# 11           Ireland                 110.3       5184 USD
# 12         Hong Kong                 107.7       4237 USD
# 13         Australia                 106.9       4576 USD
# 14             Japan                 106.8       3474 USD
# 15       New Zealand                 106.0       3556 USD
# 16           Finland                 104.8       4132 USD
# 17            Sweden                 101.9       4653 USD
# 18    United Kingdom                 101.3       3531 USD
# 19            Canada                 100.0       3864 USD
#
#     Purchasing power index
# 0                     36.8
# 1                     84.8
# 2                     90.1
# 3                     82.0
# 4                     15.8
# 5                     96.1
# 6                     55.4
# 7                     81.2
# 8                     41.7
# 9                    100.9
# 10                    81.6
# 11                    85.7
# 12                    71.8
# 13                    78.1
# 14                    59.4
# 15                    61.2
# 16                    71.9
# 17                    83.3
# 18                    63.6
# 19                    70.5

# %%
#Make sure that countries match between datasets
df19[(~df19['Country or region'].isin(living_cost['Country or region']))]
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 19            20    Czech Republic  6.852           1.269           1.487
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 19                     0.92                         0.457       0.046
#
#     Perceptions of corruption Healthcare system
# 19                      0.036  Universal public

# %%
#Checking for any word in living_cost dataframe that contains the word 'Czech'
living_cost[living_cost['Country or region'].str.contains("Czech")]
# Out:
#    Country or region  Cost of living index Monthly income  \
# 43           Czechia                  64.1       1833 USD
#
#     Purchasing power index
# 43                    52.2

# %%
#The two datasets have different names for Czech Republic/Czechia
#Need to edit in one of the datasets before combining
living_cost['Country or region'] = living_cost['Country or region'].str.replace('Czechia', 'Czech Republic')
living_cost.sort_values('Country or region').head(30)
# Out:
#          Country or region  Cost of living index Monthly income  \
# 98             Afghanistan                  33.6         45 USD
# 68                 Albania                  47.6        437 USD
# 85                 Algeria                  41.7        331 USD
# 65               Argentina                  49.4        933 USD
# 75                 Armenia                  45.1        390 USD
# 13               Australia                 106.9       4576 USD
# 24                 Austria                  96.3       4275 USD
# 87              Azerbaijan                  41.1        373 USD
# 8                  Bahamas                 116.0       2648 USD
# 76              Bangladesh                  44.6        162 USD
# 74                 Belarus                  46.6        523 USD
# 22                 Belgium                  98.3       3946 USD
# 1                  Bermuda                 190.3       8845 USD
# 71                 Bolivia                  47.3        294 USD
# 69  Bosnia and Herzegovina                  47.5        513 USD
# 50                  Brazil                  57.1        761 USD
# 73                Bulgaria                  46.9        784 USD
# 46                   Burma                  62.1        116 USD
# 42                Cambodia                  65.6        123 USD
# 19                  Canada                 100.0       3864 USD
# 0           Cayman Islands                 195.0       3928 USD
# 41                   Chile                  65.8       1251 USD
# 53                   China                  55.4        868 USD
# 84                Colombia                  41.9        543 USD
# 32              Costa Rica                  75.0        975 USD
# 44                 Croatia                  63.2       1243 USD
# 49                    Cuba                  58.6        623 USD
# 43          Czech Republic                  64.1       1833 USD
# 7                  Denmark                 118.4       5270 USD
# 45      Dominican Republic                  62.1        674 USD
#
#     Purchasing power index
# 98                     2.4
# 68                    16.7
# 85                    14.5
# 65                    34.5
# 75                    15.8
# 13                    78.1
# 24                    81.0
# 87                    16.6
# 8                     41.7
# 76                     6.6
# 74                    20.5
# 22                    73.3
# 1                     84.8
# 71                    11.4
# 69                    19.7
# 50                    24.3
# 73                    30.5
# 46                     3.4
# 42                     3.4
# 19                    70.5
# 0                     36.8
# 41                    34.7
# 53                    28.6
# 84                    23.6
# 32                    23.7
# 44                    35.8
# 49                    19.4
# 43                    52.2
# 7                     81.2
# 45                    19.8

# %%
df_combined = pd.merge(df19, living_cost, on='Country or region', how='inner')
df_combined.sort_values("Overall rank")
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 7              1           Finland  7.769           1.340           1.587
# 6              2           Denmark  7.600           1.383           1.573
# 15             3            Norway  7.554           1.488           1.582
# 9              4           Iceland  7.494           1.380           1.624
# 13             5       Netherlands  7.488           1.396           1.522
# 17             6       Switzerland  7.480           1.452           1.526
# 16             7            Sweden  7.343           1.387           1.487
# 14             8       New Zealand  7.307           1.303           1.557
# 3              9            Canada  7.278           1.365           1.505
# 1             10           Austria  7.246           1.376           1.475
# 0             11         Australia  7.228           1.372           1.548
# 4             12        Costa Rica  7.167           1.034           1.441
# 11            13            Israel  7.139           1.276           1.455
# 12            14        Luxembourg  7.090           1.609           1.479
# 18            15    United Kingdom  7.054           1.333           1.538
# 10            16           Ireland  7.021           1.499           1.553
# 8             17           Germany  6.985           1.373           1.454
# 2             18           Belgium  6.923           1.356           1.504
# 19            19     United States  6.892           1.433           1.457
# 5             20    Czech Republic  6.852           1.269           1.487
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 7                     0.986                         0.596       0.153
# 6                     0.996                         0.592       0.252
# 15                    1.028                         0.603       0.271
# 9                     1.026                         0.591       0.354
# 13                    0.999                         0.557       0.322
# 17                    1.052                         0.572       0.263
# 16                    1.009                         0.574       0.267
# 14                    1.026                         0.585       0.330
# 3                     1.039                         0.584       0.285
# 1                     1.016                         0.532       0.244
# 0                     1.036                         0.557       0.332
# 4                     0.963                         0.558       0.144
# 11                    1.029                         0.371       0.261
# 12                    1.012                         0.526       0.194
# 18                    0.996                         0.450       0.348
# 10                    0.999                         0.516       0.298
# 8                     0.987                         0.495       0.261
# 2                     0.986                         0.473       0.160
# 19                    0.874                         0.454       0.280
# 5                     0.920                         0.457       0.046
#
#     Perceptions of corruption            Healthcare system  \
# 7                       0.393  Universal government-funded
# 6                       0.410  Universal government-funded
# 15                      0.341  Universal government-funded
# 9                       0.118  Universal government-funded
# 13                      0.298            Universal private
# 17                      0.343            Universal private
# 16                      0.373  Universal government-funded
# 14                      0.380  Universal government-funded
# 3                       0.308  Universal government-funded
# 1                       0.226               Public private
# 0                       0.290  Universal government-funded
# 4                       0.093  Universal government-funded
# 11                      0.082            Universal private
# 12                      0.316             Universal public
# 18                      0.278  Universal government-funded
# 10                      0.310  Universal government-funded
# 8                       0.265               Public private
# 2                       0.210             Universal public
# 19                      0.128                Non-universal
# 5                       0.036             Universal public
#
#     Cost of living index Monthly income  Purchasing power index
# 7                  104.8       4132 USD                    71.9
# 6                  118.4       5270 USD                    81.2
# 15                 130.5       6875 USD                    96.1
# 9                  135.1       6071 USD                    82.0
# 13                  99.5       4433 USD                    81.3
# 17                 144.3       7125 USD                    90.1
# 16                 101.9       4653 USD                    83.3
# 14                 106.0       3556 USD                    61.2
# 3                  100.0       3864 USD                    70.5
# 1                   96.3       4275 USD                    81.0
# 0                  106.9       4576 USD                    78.1
# 4                   75.0        975 USD                    23.7
# 11                 118.9       3608 USD                    55.4
# 12                 111.4       6159 USD                   100.9
# 18                 101.3       3531 USD                    63.6
# 10                 110.3       5184 USD                    85.7
# 8                   90.7       4043 USD                    81.3
# 2                   98.3       3946 USD                    73.3
# 19                 100.0       5480 USD                   100.0
# 5                   64.1       1833 USD                    52.2

# %%
#Checking if any rows of df19 were dropped
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 0 to 19
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  20 non-null     int64
#  1   Country or region             20 non-null     object
#  2   Score                         20 non-null     float64
#  3   GDP per capita                20 non-null     float64
#  4   Social support                20 non-null     float64
#  5   Healthy life expectancy       20 non-null     float64
#  6   Freedom to make life choices  20 non-null     float64
#  7   Generosity                    20 non-null     float64
#  8   Perceptions of corruption     20 non-null     float64
#  9   Healthcare system             20 non-null     object
#  10  Cost of living index          20 non-null     float64
#  11  Monthly income                20 non-null     object
#  12  Purchasing power index        20 non-null     float64
# dtypes: float64(9), int64(1), object(3)
# memory usage: 2.2+ KB

# %%
#Monthly income should be an integer
df_combined=df_combined.rename(columns = {'Monthly income':'Monthly income in USD'})
df_combined['Monthly income in USD'] = df_combined['Monthly income in USD'].str.replace('USD','').astype(int)
df_combined
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             11         Australia  7.228           1.372           1.548
# 1             10           Austria  7.246           1.376           1.475
# 2             18           Belgium  6.923           1.356           1.504
# 3              9            Canada  7.278           1.365           1.505
# 4             12        Costa Rica  7.167           1.034           1.441
# 5             20    Czech Republic  6.852           1.269           1.487
# 6              2           Denmark  7.600           1.383           1.573
# 7              1           Finland  7.769           1.340           1.587
# 8             17           Germany  6.985           1.373           1.454
# 9              4           Iceland  7.494           1.380           1.624
# 10            16           Ireland  7.021           1.499           1.553
# 11            13            Israel  7.139           1.276           1.455
# 12            14        Luxembourg  7.090           1.609           1.479
# 13             5       Netherlands  7.488           1.396           1.522
# 14             8       New Zealand  7.307           1.303           1.557
# 15             3            Norway  7.554           1.488           1.582
# 16             7            Sweden  7.343           1.387           1.487
# 17             6       Switzerland  7.480           1.452           1.526
# 18            15    United Kingdom  7.054           1.333           1.538
# 19            19     United States  6.892           1.433           1.457
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                     1.036                         0.557       0.332
# 1                     1.016                         0.532       0.244
# 2                     0.986                         0.473       0.160
# 3                     1.039                         0.584       0.285
# 4                     0.963                         0.558       0.144
# 5                     0.920                         0.457       0.046
# 6                     0.996                         0.592       0.252
# 7                     0.986                         0.596       0.153
# 8                     0.987                         0.495       0.261
# 9                     1.026                         0.591       0.354
# 10                    0.999                         0.516       0.298
# 11                    1.029                         0.371       0.261
# 12                    1.012                         0.526       0.194
# 13                    0.999                         0.557       0.322
# 14                    1.026                         0.585       0.330
# 15                    1.028                         0.603       0.271
# 16                    1.009                         0.574       0.267
# 17                    1.052                         0.572       0.263
# 18                    0.996                         0.450       0.348
# 19                    0.874                         0.454       0.280
#
#     Perceptions of corruption            Healthcare system  \
# 0                       0.290  Universal government-funded
# 1                       0.226               Public private
# 2                       0.210             Universal public
# 3                       0.308  Universal government-funded
# 4                       0.093  Universal government-funded
# 5                       0.036             Universal public
# 6                       0.410  Universal government-funded
# 7                       0.393  Universal government-funded
# 8                       0.265               Public private
# 9                       0.118  Universal government-funded
# 10                      0.310  Universal government-funded
# 11                      0.082            Universal private
# 12                      0.316             Universal public
# 13                      0.298            Universal private
# 14                      0.380  Universal government-funded
# 15                      0.341  Universal government-funded
# 16                      0.373  Universal government-funded
# 17                      0.343            Universal private
# 18                      0.278  Universal government-funded
# 19                      0.128                Non-universal
#
#     Cost of living index  Monthly income in USD  Purchasing power index
# 0                  106.9                   4576                    78.1
# 1                   96.3                   4275                    81.0
# 2                   98.3                   3946                    73.3
# 3                  100.0                   3864                    70.5
# 4                   75.0                    975                    23.7
# 5                   64.1                   1833                    52.2
# 6                  118.4                   5270                    81.2
# 7                  104.8                   4132                    71.9
# 8                   90.7                   4043                    81.3
# 9                  135.1                   6071                    82.0
# 10                 110.3                   5184                    85.7
# 11                 118.9                   3608                    55.4
# 12                 111.4                   6159                   100.9
# 13                  99.5                   4433                    81.3
# 14                 106.0                   3556                    61.2
# 15                 130.5                   6875                    96.1
# 16                 101.9                   4653                    83.3
# 17                 144.3                   7125                    90.1
# 18                 101.3                   3531                    63.6
# 19                 100.0                   5480                   100.0

# %%
df_combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 20 entries, 0 to 19
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Overall rank                  20 non-null     int64
#  1   Country or region             20 non-null     object
#  2   Score                         20 non-null     float64
#  3   GDP per capita                20 non-null     float64
#  4   Social support                20 non-null     float64
#  5   Healthy life expectancy       20 non-null     float64
#  6   Freedom to make life choices  20 non-null     float64
#  7   Generosity                    20 non-null     float64
#  8   Perceptions of corruption     20 non-null     float64
#  9   Healthcare system             20 non-null     object
#  10  Cost of living index          20 non-null     float64
#  11  Monthly income in USD         20 non-null     int32
#  12  Purchasing power index        20 non-null     float64
# dtypes: float64(9), int32(1), int64(1), object(2)
# memory usage: 2.1+ KB

# %%
df_combined.describe()
# Out:
#        Overall rank      Score  GDP per capita  Social support  \
# count      20.00000  20.000000       20.000000       20.000000
# mean       10.50000   7.245500        1.371200        1.517700
# std         5.91608   0.258082        0.112049        0.051613
# min         1.00000   6.852000        1.034000        1.441000
# 25%         5.75000   7.045750        1.338250        1.478000
# 50%        10.50000   7.237000        1.374500        1.513500
# 75%        15.25000   7.482000        1.405250        1.554000
# max        20.00000   7.769000        1.609000        1.624000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count                 20.00000                      20.00000   20.000000
# mean                   0.99895                       0.53215    0.253250
# std                    0.04180                       0.06346    0.078681
# min                    0.87400                       0.37100    0.046000
# 25%                    0.98675                       0.48950    0.231500
# 50%                    1.00400                       0.55700    0.265000
# 75%                    1.02650                       0.58425    0.304000
# max                    1.05200                       0.60300    0.354000
#
#        Perceptions of corruption  Cost of living index  Monthly income in USD  \
# count                  20.000000              20.00000              20.000000
# mean                    0.259900             105.68500            4479.450000
# std                     0.112959              18.55187            1505.578066
# min                     0.036000              64.10000             975.000000
# 25%                     0.189500              99.20000            3800.000000
# 50%                     0.294000             103.35000            4354.000000
# 75%                     0.341500             113.15000            5322.500000
# max                     0.410000             144.30000            7125.000000
#
#        Purchasing power index
# count               20.000000
# mean                75.640000
# std                 18.130358
# min                 23.700000
# 25%                 68.775000
# 50%                 81.100000
# 75%                 83.900000
# max                100.900000

# %% [markdown]
# ## Univariate exploration

# %%
#for _ in range(1000):
    #bootreps = np.array([np.random.choice(df_combined['GDP per capita'], len(df_combined), replace = True)

# %%
#Histogram of GPD per capita
df_combined['GDP per capita'].hist()
plt.axvline(x=df_combined['GDP per capita'].mean(), color='red')
plt.title('Histogram of GDP per Capita of top 20 happiest countries')
plt.xlabel('GDP per capita')
plt.ylabel('Number of countries');

# %%
df_combined[df_combined['GDP per capita'] < 1.1]
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 4            12        Costa Rica  7.167           1.034           1.441
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                    0.963                         0.558       0.144
#
#    Perceptions of corruption            Healthcare system  \
# 4                      0.093  Universal government-funded
#
#    Cost of living index  Monthly income in USD  Purchasing power index
# 4                  75.0                    975                    23.7

# %% [markdown]
# The distribution of GDP per capita is right skewed with an outlier of Costa Rica at 1.034

# %%
#Histogram of social support
df_combined['Social support'].hist()
plt.axvline(x=df_combined['Social support'].mean(), color='red')
plt.title('Histogram of Social support of top 20 happiest countries')
plt.xlabel('Social support')
plt.ylabel('Number of countries');

# %%
df_combined[df_combined['Social support'] > 1.6]
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 9             4           Iceland  7.494            1.38           1.624
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 9                    1.026                         0.591       0.354
#
#    Perceptions of corruption            Healthcare system  \
# 9                      0.118  Universal government-funded
#
#    Cost of living index  Monthly income in USD  Purchasing power index
# 9                 135.1                   6071                    82.0

# %% [markdown]
# The distribution of Social support is multimodal with an outlier of Iceland at 1.624

# %%
#Histogram of Healthy life expectancy
df_combined['Healthy life expectancy'].hist()
plt.axvline(x=df_combined['Healthy life expectancy'].mean(), color='red')
plt.title('Histogram of Healthy life expectancy of top 20 happiest countries')
plt.xlabel('Healthy life expectancy')
plt.ylabel('Number of countries');

# %%
df_combined[df_combined['Healthy life expectancy'] < 0.975]
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 4             12        Costa Rica  7.167           1.034           1.441
# 5             20    Czech Republic  6.852           1.269           1.487
# 19            19     United States  6.892           1.433           1.457
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 4                     0.963                         0.558       0.144
# 5                     0.920                         0.457       0.046
# 19                    0.874                         0.454       0.280
#
#     Perceptions of corruption            Healthcare system  \
# 4                       0.093  Universal government-funded
# 5                       0.036             Universal public
# 19                      0.128                Non-universal
#
#     Cost of living index  Monthly income in USD  Purchasing power index
# 4                   75.0                    975                    23.7
# 5                   64.1                   1833                    52.2
# 19                 100.0                   5480                   100.0

# %% [markdown]
# The distribution of Healthy life expectancy is right skewed with outliers of Costa Rica, Czech Republic, and the United States.

# %%
#Histogram of Freedom to make life choices
df_combined['Freedom to make life choices'].hist()
plt.axvline(x=df_combined['Freedom to make life choices'].mean(), color='red')
plt.title('Histogram of Freedom to make life choices of top 20 happiest countries')
plt.xlabel('Freedom to make life choices')
plt.ylabel('Number of countries');

# %%
df_combined[df_combined['Freedom to make life choices'] < 0.4]
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 11            13            Israel  7.139           1.276           1.455
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 11                    1.029                         0.371       0.261
#
#     Perceptions of corruption  Healthcare system  Cost of living index  \
# 11                      0.082  Universal private                 118.9
#
#     Monthly income in USD  Purchasing power index
# 11                   3608                    55.4

# %%
df_combined[(df_combined['Freedom to make life choices'] > 0.4) & (df_combined['Freedom to make life choices'] < 0.55) ]
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 1             10           Austria  7.246           1.376           1.475
# 2             18           Belgium  6.923           1.356           1.504
# 5             20    Czech Republic  6.852           1.269           1.487
# 8             17           Germany  6.985           1.373           1.454
# 10            16           Ireland  7.021           1.499           1.553
# 12            14        Luxembourg  7.090           1.609           1.479
# 18            15    United Kingdom  7.054           1.333           1.538
# 19            19     United States  6.892           1.433           1.457
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 1                     1.016                         0.532       0.244
# 2                     0.986                         0.473       0.160
# 5                     0.920                         0.457       0.046
# 8                     0.987                         0.495       0.261
# 10                    0.999                         0.516       0.298
# 12                    1.012                         0.526       0.194
# 18                    0.996                         0.450       0.348
# 19                    0.874                         0.454       0.280
#
#     Perceptions of corruption            Healthcare system  \
# 1                       0.226               Public private
# 2                       0.210             Universal public
# 5                       0.036             Universal public
# 8                       0.265               Public private
# 10                      0.310  Universal government-funded
# 12                      0.316             Universal public
# 18                      0.278  Universal government-funded
# 19                      0.128                Non-universal
#
#     Cost of living index  Monthly income in USD  Purchasing power index
# 1                   96.3                   4275                    81.0
# 2                   98.3                   3946                    73.3
# 5                   64.1                   1833                    52.2
# 8                   90.7                   4043                    81.3
# 10                 110.3                   5184                    85.7
# 12                 111.4                   6159                   100.9
# 18                 101.3                   3531                    63.6
# 19                 100.0                   5480                   100.0

# %% [markdown]
# The distribution of Freedom to make life choices is multimodal and left skewed. There is an outlier of Isreal at 0.371. There are 8 countries that fall between .454 (United States) and 0.532 (Austria).

# %%
#Histogram of Generosity
df_combined['Generosity'].hist()
plt.axvline(x=df_combined['Generosity'].mean(), color='red')
plt.title('Histogram of Generosity of top 20 happiest countries')
plt.xlabel('Generosity')
plt.ylabel('Number of countries');

# %%
df_combined[df_combined['Generosity'] < 0.1]
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 5            20    Czech Republic  6.852           1.269           1.487
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 5                     0.92                         0.457       0.046
#
#    Perceptions of corruption Healthcare system  Cost of living index  \
# 5                      0.036  Universal public                  64.1
#
#    Monthly income in USD  Purchasing power index
# 5                   1833                    52.2

# %%
df_combined[(df_combined['Generosity'] > 0.1) & (df_combined['Generosity'] < 0.2) ]
# Out:
#     Overall rank Country or region  Score  GDP per capita  Social support  \
# 2             18           Belgium  6.923           1.356           1.504
# 4             12        Costa Rica  7.167           1.034           1.441
# 7              1           Finland  7.769           1.340           1.587
# 12            14        Luxembourg  7.090           1.609           1.479
#
#     Healthy life expectancy  Freedom to make life choices  Generosity  \
# 2                     0.986                         0.473       0.160
# 4                     0.963                         0.558       0.144
# 7                     0.986                         0.596       0.153
# 12                    1.012                         0.526       0.194
#
#     Perceptions of corruption            Healthcare system  \
# 2                       0.210             Universal public
# 4                       0.093  Universal government-funded
# 7                       0.393  Universal government-funded
# 12                      0.316             Universal public
#
#     Cost of living index  Monthly income in USD  Purchasing power index
# 2                   98.3                   3946                    73.3
# 4                   75.0                    975                    23.7
# 7                  104.8                   4132                    71.9
# 12                 111.4                   6159                   100.9

# %%
#DISCUSS DISTRIBUTION OF GENEROSITY

# %%
#Histogram of Perceptions of corruption
df_combined['Perceptions of corruption'].hist()
plt.axvline(x=df_combined['Perceptions of corruption'].mean(), color='red')
plt.title('Histogram of Perceptions of corruption of top 20 happiest countries')
plt.xlabel('Perceptions of corruption')
plt.ylabel('Number of countries');

# %% [markdown]
# The distribution of Perceptions of corruption is multimodal and left skewed.

# %%
#Viewing the distribution of healthcare systems
df_combined['Healthcare system'].value_counts().plot(kind='bar', figsize=(8,5), align='center')
plt.xticks(rotation=45, ha='right')
plt.title('Number of Top 20 Happiest Countries per Healthcare system')
plt.xlabel('Healthcare system')
plt.ylabel('Count');

# %% [markdown]
# Over 1/2 of the top 20 happiest countries have a universal government funded healthcare system.

# %%
#Histogram of Cost of living index
df_combined['Cost of living index'].hist()
plt.axvline(x=df_combined['Cost of living index'].mean(), color='red')
plt.title('Histogram of Cost of living index of top 20 happiest countries')
plt.xlabel('Cost of living index')
plt.ylabel('Number of countries');

# %%
#FIGURE THE COUNTRIES IN SKEWED POSITIONS

# %%
#Histogram of Monthly income in USD
df_combined['Monthly income in USD'].hist()
plt.axvline(x=df_combined['Monthly income in USD'].mean(), color='red')
plt.title('Histogram of Monthly income in USD of top 20 happiest countries')
plt.xlabel('Monthly income in USD')
plt.ylabel('Number of countries');

# %%
#DESCRIBE DISTRIBUTION

# %%
#Histogram of Purchasing power index
df_combined['Purchasing power index'].hist()
plt.axvline(x=df_combined['Purchasing power index'].mean(), color='red')
plt.title('Histogram of Purchasing power index of top 20 happiest countries')
plt.xlabel('Purchasing power index')
plt.ylabel('Number of countries');

# %%
#DESCRIBE DISTRUBTION AND SKEWED RESULTS

# %% [markdown]
# ## Bivariate Exploration
# I'm interested in investigating life expectancy, freedom to make life choices, healthcare systems, cost of living, and monthly income to happiness ratings.

# %%
#Compare happiness rating with life expectancy
from adjustText import adjust_text
x = df_combined['Score']
y = df_combined['Healthy life expectancy']
n = df_combined['Country or region']

fig, ax = plt.subplots(figsize = (12, 9))
ax.scatter(x, y)
plt.title('Top 20 Happiness Scores Compared to Healthy Life Expectancy')
plt.xlabel('Happiness Score')
plt.ylabel('Life Expectancy')

texts = []
for i, txt in enumerate( n ):
    texts.append(ax.text(x[i], y[i], txt))
adjust_text(texts)
plt.show();

# %%
#Compare happiness rating with freedom to make life choices
y = df_combined['Freedom to make life choices']

fig, ax = plt.subplots(figsize = (12, 9))
ax.scatter(x, y)
plt.title('Top 20 Happiness Scores Compared to Freedom to Make Life Choices')
plt.xlabel('Happiness Score')
plt.ylabel('Freedom to make life choices')

texts = []
for i, txt in enumerate( n ):
    texts.append(ax.text(x[i], y[i], txt))
adjust_text(texts)
plt.show();

# %%
df_combined.groupby('Healthcare system')['Score'].mean().plot(kind='bar')
plt.xticks(rotation=45, ha='right')
plt.show;

# %%
#Compare happiness rating with healthcare systems
healthcare_percent = (df_combined.groupby('Healthcare system')['Country or region'].count()/20)*100
healthcare_percent_order
# Out:
# Healthcare system
# Non-universal                   5.0
# Public private                 10.0
# Universal government-funded    55.0
# Universal private              15.0
# Universal public               15.0
# Name: Country or region, dtype: float64

# %%
plt.subplots(figsize=(9,6))
healthcare_range = np.array(['Universal government_funded', 'Universal Public', 'Universal Private', 'Public Private', 'Non-universal'])
healthcare_perc = np.array([55, 15, 15, 10, 5])
plt.bar(healthcare_range, healthcare_perc)
plt.xticks(rotation=45, ha='right')
plt.title('Percent of Top 20 Happiest Countries Compared to Healthcare System')
plt.xlabel('Healthcare System')
plt.ylabel('Percentage')

plt.show;

# %%
#Compare happiness rating with cost of living

y = df_combined['Cost of living index']

fig, ax = plt.subplots(figsize = (12, 9))
ax.scatter(x, y)
plt.title('Top 20 Happiness Scores Compared to Freedom to Cost of Living Index')
plt.xlabel('Happiness Score')
plt.ylabel('Cost of Living Index')

texts = []
for i, txt in enumerate( n ):
    texts.append(ax.text(x[i], y[i], txt))
adjust_text(texts)
plt.show();

# %%
#Compare happiness rating with monthly income
y = df_combined['Monthly income in USD']

fig, ax = plt.subplots(figsize = (12, 9))
ax.scatter(x, y)
plt.title('Top 20 Happiness Scores Compared to Monthly income in USD')
plt.xlabel('Happiness Score')
plt.ylabel('Monthly income in USD')

texts = []
for i, txt in enumerate( n ):
    texts.append(ax.text(x[i], y[i], txt))
adjust_text(texts)
plt.show();
